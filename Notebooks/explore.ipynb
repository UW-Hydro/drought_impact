# %% [markdown]
# # Explore Data

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

import xarray as xr
import pandas as pd

data_dir = "/pool0/home/steinadi/data/wa_drought/DatabaseDrafts"
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Config Reading Settings

# %%
# Contains Data, good to go
# -------------------------
# pd.read_excel(f"{data_dir}/DroughtDeclarations_WA_OR.xlsx", skiprows=np.arange(1,38), index_col=0, header=1, usecols="A:M")
# pd.read_excel(f"{data_dir}/DroughtPermits_WA_1994_to_2019.xlsx", skiprows=np.arange(1,7), index_col=0, header=1)
# pd.read_excel(f"{data_dir}/FireDangerRating_WA_2010_2020.xlsx", skiprows=np.arange(1,13),index_col=0,header=1)
# pd.read_excel(f"{data_dir}/FireDangerRatings_OR_ODF_2020.xlsx", skiprows=np.arange(1,15), index_col=0, header=1)
# pd.read_excel(f"{data_dir}/FireClosures_OR_ODF_2011-2020.xlsx", skiprows=np.arange(1,13), header=1, sheet_name="2011-2020") # object index
# pd.read_excel(f"{data_dir}/RedFlagWarnings_WA_OR.xlsx", skiprows=np.arange(1,32), header=1) # object index
# pd.read_excel(f"{data_dir}/WaterRightsTransfers_OR.xlsx", skiprows=np.arange(1,7), header=1, index_col=[0,1])
# pd.read_excel(f"{data_dir}/NationalPark_visitations.xlsx", skiprows=np.arange(1,18), header=1, sheet_name="Recreation Visits", index_col=[0,1,2], usecols='B:Q')
# pd.read_excel(f"{data_dir}/NationalPark_visitations.xlsx", skiprows=np.arange(1,20), header=1, sheet_name="Overnight", usecols='B:N', index_col=[0,1,2])
# pd.read_excel(f"{data_dir}/StatePark_Visitations.xlsx", sheet_name="WA Overnight", skiprows=np.arange(1,5), usecols='B:Q', index_col=[0,1,2], header=1)
# pd.read_excel(f"{data_dir}/StatePark_Visitations.xlsx", sheet_name="WA Total", skiprows=np.arange(1,5), usecols='B:Q', index_col=[0,1,2], header=1)
# pd.read_excel(f"{data_dir}/StatePark_Visitations.xlsx", sheet_name="WA Day Use", skiprows=np.arange(1,5), usecols='B:Q', index_col=[0,1,2], header=1)
# pd.read_excel(f"{data_dir}/StatePark_Visitations.xlsx", sheet_name="OR Day User Monthly", skiprows=np.arange(1,4), index_col=[0,1,2], header=1)
# pd.read_excel(f"{data_dir}/StatePark_Visitations.xlsx", sheet_name="OR Overnight Monthly", skiprows=np.arange(1,4), index_col=[0,1,2], header=1)

# Contains Data, can be spliced in pandas
# ---------------------------------------
# pd.read_excel(f"{data_dir}/StatePark_Visitations.xlsx", sheet_name="OR Annual Day Use", skiprows=np.arange(1,6), index_col=0, header=1) # some totals that I think can be cut out?
# pd.read_excel(f"{data_dir}/StatePark_Visitations.xlsx", sheet_name="OR Annual Overnight", skiprows=np.arange(1,7), index_col=2, header=1) # also some strange totals

# Contains Data, needs editing outside pandas
# -------------------------------------------
# pd.read_excel(f"{data_dir}/FireClosures_Fire Restrictions-USFS.xlsx", skiprows=np.arange(1,16), header=1) # needs cleaning up
# pd.read_excel(f"{data_dir}/FireClosures_OR_ODF_2011-2020.xlsx", sheet_name="2018 Days Per Level") # needs cleaning up and context
# pd.read_excel(f"{data_dir}/FireClosures_Restrictions-BLM.xlsx") # needs cleaning up
# pd.read_excel(f"{data_dir}/FireSeason_OR.xlsx", skiprows=np.arange(1,9), index_col=0, usecols="A,B:V", header=1, sheet_name="By District") # needs to be split into different datasets
# pd.read_excel(f"{data_dir}/FireSeason_OR.xlsx", sheet_name="Avg") # needs transposition and header names

# Empty
# -----
# pd.read_excel(f"{data_dir}/BurnRestrictions_OR.xlsx")
# pd.read_excel(f"{data_dir}/BurnRestrictions_WA.xlsx")
# pd.read_excel(f"{data_dir}/Database - FireDangerRestrictions.xlsx")

# copy a file from above to read it!
test = 
test
# Out:
#                                          Region Number      Region Name  \
# Campground
# ALFRED A LOEB STATE PARK                           1.0          Coastal
# BEACHSIDE STATE RECREATION SITE                    1.0          Coastal
# BEVERLY BEACH STATE PARK                           1.0          Coastal
# BULLARDS BEACH STATE PARK                          1.0          Coastal
# CAPE BLANCO STATE PARK                             1.0          Coastal
# ...                                                ...              ...
# UNITY LAKE STATE RECREATION SITE                   3.0  Mountain Region
# VALLEY OF THE ROGUE STATE RECREATN AREA            3.0  Mountain Region
# WALLOWA LAKE STATE RECREATION AREA                 3.0  Mountain Region
# Total: Region 3                                    NaN              NaN
# Total Statewide                                    NaN              NaN
#
#                                               2002       2003       2004  \
# Campground
# ALFRED A LOEB STATE PARK                   18697.8    21621.6    20760.3
# BEACHSIDE STATE RECREATION SITE            36898.4    36658.2    39375.9
# BEVERLY BEACH STATE PARK                  161448.9   160103.3   163722.6
# BULLARDS BEACH STATE PARK                 111358.8   104682.1   105203.0
# CAPE BLANCO STATE PARK                     38974.0    36143.3    35887.5
# ...                                            ...        ...        ...
# UNITY LAKE STATE RECREATION SITE            7638.9     7321.2     7132.7
# VALLEY OF THE ROGUE STATE RECREATN AREA    90320.1    89744.6    88688.1
# WALLOWA LAKE STATE RECREATION AREA         75530.2    77088.4    76695.8
# Total: Region 3                           592202.0   585871.2   592110.9
# Total Statewide                          2380910.5  2383534.2  2381379.0
#
#                                               2005       2006       2007  \
# Campground
# ALFRED A LOEB STATE PARK                   21509.4    19559.1    19668.0
# BEACHSIDE STATE RECREATION SITE            35775.7    36970.3    37631.1
# BEVERLY BEACH STATE PARK                  156681.7   155719.7   148342.8
# BULLARDS BEACH STATE PARK                 103397.2   102227.0   103709.3
# CAPE BLANCO STATE PARK                     29522.7    28125.2    34010.3
# ...                                            ...        ...        ...
# UNITY LAKE STATE RECREATION SITE            6919.0     7516.9     7122.4
# VALLEY OF THE ROGUE STATE RECREATN AREA    85365.8    84056.7    91066.4
# WALLOWA LAKE STATE RECREATION AREA         73037.5    69175.8    71147.0
# Total: Region 3                           581976.7   567504.7   580914.2
# Total Statewide                          2318074.4  2305651.4  2362409.4
#
#                                               2008       2009  ...       2011  \
# Campground                                                     ...
# ALFRED A LOEB STATE PARK                   20836.2    20282.0  ...    18008.1
# BEACHSIDE STATE RECREATION SITE            35311.4    39878.2  ...    35562.4
# BEVERLY BEACH STATE PARK                  146209.1   159045.1  ...   149622.7
# BULLARDS BEACH STATE PARK                  98945.1    98675.7  ...    97059.7
# CAPE BLANCO STATE PARK                     30842.6    38032.8  ...    32389.3
# ...                                            ...        ...  ...        ...
# UNITY LAKE STATE RECREATION SITE            5496.3     8197.6  ...     7488.4
# VALLEY OF THE ROGUE STATE RECREATN AREA    86003.1    88762.6  ...    76663.6
# WALLOWA LAKE STATE RECREATION AREA         66775.7    78774.4  ...    71431.4
# Total: Region 3                           550891.3   600855.2  ...   562346.7
# Total Statewide                          2327464.4  2515651.6  ...  2307740.9
#
#                                               2012       2013       2014  \
# Campground
# ALFRED A LOEB STATE PARK                   19588.8    18674.7    19044.3
# BEACHSIDE STATE RECREATION SITE            34641.9    36203.2    37898.2
# BEVERLY BEACH STATE PARK                  142565.5     148077   150634.2
# BULLARDS BEACH STATE PARK                 100132.4    93621.8    96776.5
# CAPE BLANCO STATE PARK                     30697.5      34550      37408
# ...                                            ...        ...        ...
# UNITY LAKE STATE RECREATION SITE            6881.1     6384.5     4993.2
# VALLEY OF THE ROGUE STATE RECREATN AREA    76957.9    70313.1    83562.6
# WALLOWA LAKE STATE RECREATION AREA         72905.8    71628.4    77879.9
# Total: Region 3                           561254.3   569864.2   598286.7
# Total Statewide                          2319078.1  2411954.3  2491805.4
#
#                                               2015 2016 (updated 2/1/2017)  \
# Campground
# ALFRED A LOEB STATE PARK                   24654.3                   26456
# BEACHSIDE STATE RECREATION SITE            40382.4                   39671
# BEVERLY BEACH STATE PARK                  165824.8                  165296
# BULLARDS BEACH STATE PARK                 105976.3                  104022
# CAPE BLANCO STATE PARK                     38031.2                   36807
# ...                                            ...                     ...
# UNITY LAKE STATE RECREATION SITE            5051.3                    5340
# VALLEY OF THE ROGUE STATE RECREATN AREA    97387.5                  103022
# WALLOWA LAKE STATE RECREATION AREA         78687.5                   68916
# Total: Region 3                           611679.4                  677416
# Total Statewide                          2590941.9                 2741578
#
#                                         2017 (updated 1/30/2018)  \
# Campground
# ALFRED A LOEB STATE PARK                                   21325
# BEACHSIDE STATE RECREATION SITE                            40863
# BEVERLY BEACH STATE PARK                                  169389
# BULLARDS BEACH STATE PARK                                 103458
# CAPE BLANCO STATE PARK                                     37750
# ...                                                          ...
# UNITY LAKE STATE RECREATION SITE                            5340
# VALLEY OF THE ROGUE STATE RECREATN AREA                   112724
# WALLOWA LAKE STATE RECREATION AREA                         83783
# Total: Region 3                                           692123
# Total Statewide                                          2788358
#
#                                         2018 (updated 2-4-2019)  \
# Campground
# ALFRED A LOEB STATE PARK                                  26657
# BEACHSIDE STATE RECREATION SITE                           44274
# BEVERLY BEACH STATE PARK                                 157310
# BULLARDS BEACH STATE PARK                                116410
# CAPE BLANCO STATE PARK                                    39753
# ...                                                         ...
# UNITY LAKE STATE RECREATION SITE                           5591
# VALLEY OF THE ROGUE STATE RECREATN AREA                  107850
# WALLOWA LAKE STATE RECREATION AREA                        88524
# Total: Region 3                                          691173
# Total Statewide                                         2891665
#
#                                         2019 (updated 2-3-2020)  \
# Campground
# ALFRED A LOEB STATE PARK                                26644.2
# BEACHSIDE STATE RECREATION SITE                         42443.3
# BEVERLY BEACH STATE PARK                               167916.3
# BULLARDS BEACH STATE PARK                              117374.2
# CAPE BLANCO STATE PARK                                  38475.1
# ...                                                         ...
# UNITY LAKE STATE RECREATION SITE                           6369
# VALLEY OF THE ROGUE STATE RECREATN AREA                103166.0
# WALLOWA LAKE STATE RECREATION AREA                      95995.4
# Total: Region 3                                          735594
# Total Statewide                                       2953536.7
#
#                                         2020 (updated 2/2/2021)
# Campground
# ALFRED A LOEB STATE PARK                                 1930.5
# BEACHSIDE STATE RECREATION SITE                          8510.7
# BEVERLY BEACH STATE PARK                               113212.7
# BULLARDS BEACH STATE PARK                               84055.5
# CAPE BLANCO STATE PARK                                   3559.1
# ...                                                         ...
# UNITY LAKE STATE RECREATION SITE                         5157.8
# VALLEY OF THE ROGUE STATE RECREATN AREA                 64173.3
# WALLOWA LAKE STATE RECREATION AREA                      79547.7
# Total: Region 3                                        548447.1
# Total Statewide                                         1931828
#
# [61 rows x 21 columns]

# %% [markdown]
# ## List Counties

# %%
# https://www.officialusa.com/stateguides/washington/county/
wa_counties = ["Adams", "Asotin", "Benton", "Chelan", "Clallam", "Clark", "Columbia", "Cowlitz", "Douglas", "Ferry", "Franklin", "Garfield", "Grant", "Grays Harbor", "Island", "Jefferson", "King", "Kitsap", "Kittitas", "Klickitat", "Lewis", "Lincoln", "Mason", "Okanogan", "Pacific", "Pend Oreille", "Pierce", "San Juan", "Skagit", "Skamania", "Snohomish", "Spokane", "Stevens", "Thurston", "Wahkiakum", "Walla Walla", "Whatcom", "Whitman", "Yakima"]

or_counties = ["Baker", "Benton", "Clackamas", "Clatsop", "Columbia", "Coos", "Crook", "Curry", "Deschutes", "Douglas", "Gilliam", "Grant", "Harney", "Hood River", "Jackson", "Jefferson", "Josephine", "Klamath", "Lake", "Lane", "Lincoln", "Linn", "Malheur", "Marion", "Morrow", "Multnomah", "Polk", "Sherman", "Tillamook", "Umatilla", "Union", "Wallowa", "Wasco", "Washington", "Wheeler", "Yamhill"]

# %% [markdown]
# Check what counties are in the dataset and what we are missing in the above list.

# %%
wa_rep = []
or_rep = []
not_found = []

wa_counties_lower = [wa_county.lower() for wa_county in wa_counties]
or_counties_lower = [or_county.lower() for or_county in or_counties]

for col in test.columns:
    if "County" in col or "COUNTY"in col:
        col = col[:-7]
    col = col.lower()
    if col in wa_counties_lower:
        wa_rep.append(col)
    elif col in or_counties_lower:
        or_rep.append(col)
    else:
        not_found.append(col)

print(len(wa_rep))
print(len(or_rep))
print(len(not_found))
# Out:
# 57
# 0
# 23

# %% [markdown]
# -----------------------------------------------------
# ## Other counties found:
#
#
# **FireDangerRating_WA_2010_2020.xlsx**
#
# ['valley fdra', 'chelan fdra', 'blue mountain grass and brush fdra', 'foothills fdra', 'highlands fdra', 'kaniksu fdra', 'lower basin fdra', 'methow fdra', 'lower yakima fdra', 'northern blue mountains fdra', 'upper yakima fdra', 'upper basin fdra', 'blue mountain grass and brush', 'northern blue mountains ', 'foothills ', 'highlands ', 'kaniksu ', 'methow ', 'upper basin ', 'chelan ', 'valley ', 'lower yakima ', 'upper yakima ']
