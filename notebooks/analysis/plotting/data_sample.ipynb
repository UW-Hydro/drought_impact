# %%
import xarray as xr
import matplotlib as mpl
import matplotlib.pyplot as plt

import sys
sys.path.append('../../../')
import ndrought.plotting as ndp
# Out:
# /pool0/data/steinjao/drought/drought_impact/notebooks/analysis/plotting/../../../ndrought/wrangle.py:17: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
dm_path = '/pool0/home/steinjao/data/drought/drought_impact/data/drought_measures'

# %%
pdsi = xr.open_dataset(f'{dm_path}/pdsi/pdsi.nc')

# %%
usdm = xr.open_dataset(f'{dm_path}/usdm/USDM_CONUS_20000104_20220412.nc')

# %%
spi30d = xr.open_dataset(f'{dm_path}/spi/spi30d.nc')

# %%
spi180d = xr.open_dataset(f'{dm_path}/spi/spi180d.nc')

# %%
spei30d = xr.open_dataset(f'{dm_path}/spei/spei30d.nc')

# %%
spei180d = xr.open_dataset(f'{dm_path}/spei/spei180d.nc')

# %%
fdsi = xr.open_dataset(f'{dm_path}/fdsi/fdsi.nc')

# %%
eddi30d = xr.open_dataset(f'{dm_path}/eddi/eddi30d.nc')

# %%
eddi180d = xr.open_dataset(f'{dm_path}/eddi/eddi180d.nc')

# %%
fig, ax = plt.subplots(figsize=(15,5))

pdsi.sel(day='2021-12-31')['pdsi'].plot(ax=ax)
ax.set_aspect('equal')

# %%
fig, ax = plt.subplots(figsize=(15,5))

usdm.sel(date='2021-12-28')['USDM'].plot(vmin=-1, vmax=4, cmap=ndp.usdm_cmap(), ax=ax)
ax.set_facecolor('k')
ax.set_aspect('equal')
fig.set_facecolor('w')
ax.set_title('USDM: 12-28-2021')
# Out:
# Text(0.5, 1.0, 'USDM: 12-28-2021')

# %%
fig, ax = plt.subplots(figsize=(15,5))

spi30d.sel(day='2021-12-31')['spi'].plot(ax=ax)
ax.set_aspect('equal')
fig.set_facecolor('w')
ax.set_title('SPI30d: 12-31-2021')
# Out:
# Text(0.5, 1.0, 'SPI30d: 12-31-2021')

# %%
fig, ax = plt.subplots(figsize=(15,5))

spi180d.sel(day='2021-12-31')['spi'].plot(ax=ax)
ax.set_aspect('equal')
fig.set_facecolor('w')
ax.set_title('SPI180d: 12-31-2021')
# Out:
# Text(0.5, 1.0, 'SPI180d: 12-31-2021')

# %%
fig, ax = plt.subplots(figsize=(15,5))

spei30d.sel(day='2021-12-31')['spei'].plot(ax=ax)
ax.set_aspect('equal')
fig.set_facecolor('w')
ax.set_title('SPEI30d: 12-31-2021')
# Out:
# Text(0.5, 1.0, 'SPEI30d: 12-31-2021')

# %%
fig, ax = plt.subplots(figsize=(15,5))

spei180d.sel(day='2021-12-31')['spei'].plot(ax=ax)
ax.set_aspect('equal')
fig.set_facecolor('w')
ax.set_title('SPEI180d: 12-31-2021')
# Out:
# Text(0.5, 1.0, 'SPEI180d: 12-31-2021')

# %%
fig, ax = plt.subplots(figsize=(15,5))

eddi30d.sel(day='2021-12-31')['eddi'].plot(ax=ax)
ax.set_aspect('equal')
fig.set_facecolor('w')
ax.set_title('EDDI30d: 12-31-2021')
# Out:
# Text(0.5, 1.0, 'EDDI30d: 12-31-2021')

# %%
fig, ax = plt.subplots(figsize=(15,5))

eddi180d.sel(day='2021-12-31')['eddi'].plot(ax=ax)
ax.set_aspect('equal')
fig.set_facecolor('w')
ax.set_title('EDDI180d: 12-31-2021')
# Out:
# Text(0.5, 1.0, 'EDDI180d: 12-31-2021')
