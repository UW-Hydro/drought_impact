# %% [markdown]
# # Stacked Events Plotting
# 4.10.2023 a. stein
#
# Compare usdm & spi at D1 and D2 thresholds

# %%
import pickle
import numpy as np

import sys
sys.path.append('../../')
import ndrought.drought_network as dnet
import ndrought.wrangle_v11 as dnw

import matplotlib as mpl
import matplotlib.pyplot as plt

import pandas as pd
import xarray as xr

# %% [markdown]
# Load Data

# %%
dnet_path = '/pool0/home/steinjao/data/drought/drought_impact/data/drought_measures/ndrought_products/CONUS_105W/individual_dnet'

# %%
d1_tag = 'net_fe3_d1_rt20p_paired.pickle'
d2_tag = 'net_fe2_d2_rt20p_paired.pickle'

# %%
usdm_d1 = dnet.DroughtNetwork.unpickle(f'{dnet_path}/USDM_{d1_tag}')
usdm_d2 = dnet.DroughtNetwork.unpickle(f'{dnet_path}/USDM_{d2_tag}')

# %%
spi30d_d1 = dnet.DroughtNetwork.unpickle(f'{dnet_path}/spi_30d_{d1_tag}')
spi30d_d2 = dnet.DroughtNetwork.unpickle(f'{dnet_path}/spi_30d_{d2_tag}')

# %%
spi180d_d1 = dnet.DroughtNetwork.unpickle(f'{dnet_path}/spi_180d_{d1_tag}')
spi180d_d2 = dnet.DroughtNetwork.unpickle(f'{dnet_path}/spi_180d_{d2_tag}')

# %% [markdown]
# Plot

# %%
fig, ax = plt.subplots(figsize=(15,5))

usdm_d1.stacked_events_plot(edgecolor='k', ax=ax)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Area in Drought Event'>

# %%
fig, ax = plt.subplots(figsize=(15,5))

usdm_d2.stacked_events_plot(edgecolor='k', ax=ax)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Area in Drought Event'>

# %%
fig, ax = plt.subplots(figsize=(15,5))

spi30d_d1.stacked_events_plot(edgecolor='k', ax=ax)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Area in Drought Event'>

# %%
fig, ax = plt.subplots(figsize=(15,5))

spi30d_d2.stacked_events_plot(edgecolor='k', ax=ax)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Area in Drought Event'>

# %%
fig, ax = plt.subplots(figsize=(15,5))

spi180d_d1.stacked_events_plot(edgecolor='k', ax=ax)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Area in Drought Event'>

# %%
fig, ax = plt.subplots(figsize=(15,5))

spi180d_d2.stacked_events_plot(edgecolor='k', ax=ax)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Area in Drought Event'>
