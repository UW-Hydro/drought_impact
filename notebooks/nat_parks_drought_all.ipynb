# %% [markdown]
# # National Parks Drought Indicators - All
#
# Now that I've got more drought indicators and more park geometry, let's see what we can get up to ...

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

import xarray as xr
import pandas as pd
from netCDF4 import Dataset
from tqdm.autonotebook import tqdm
import geopandas as gpd
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /pool0/data/steinadi/.conda/envs/sedi/lib/python3.7/site-packages/ipykernel_launcher.py:9: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   if __name__ == '__main__':

# %%
fdsi = xr.open_dataset('../data/drought_measures/fdsi.nc')
fdsi
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 585, lon: 1386, time: 41, year: 41)
# Coordinates:
#   * lat      (lat) float64 49.4 49.36 49.32 49.28 ... 25.19 25.15 25.11 25.07
#   * lon      (lon) float64 -124.8 -124.7 -124.7 -124.6 ... -67.14 -67.1 -67.06
#   * time     (time) object 1980-01-14 00:00:00 ... 2020-01-14 00:00:00
#   * year     (year) int32 1980 1981 1982 1983 1984 ... 2016 2017 2018 2019 2020
# Data variables:
#     fdsi     (year, lat, lon) float32 ...
# Attributes: (12/22)
#     geospatial_bounds_crs:           EPSG:4326
#     Conventions:                     CF-1.6
#     geospatial_bounds:               POLYGON((-124.7666666333333 49.400000000...
#     geospatial_lat_min:              25.066666666666666
#     geospatial_lat_max:              49.40000000000000
#     geospatial_lon_min:              -124.7666666333333
#     ...                              ...
#     note3:                           Data in slices after last_permanent_slic...
# ...

# %% [markdown]
# Let's see if we can't make a little animation magic ...
#
# ~~following this: https://stackoverflow.com/questions/21487916/animating-a-quadmesh-from-pcolormesh-with-matplotlib~~
# (nevermind, that wasn't that useful)

# %%
from matplotlib import animation

# %%
fdsi['fdsi'].isel(year=0).plot()

# %% [markdown]
# fig = plt.figure()
#
# #plt.hold(True) # this is old code, now removed
# #plt.pcolormesh(X[0:1], Y[0:1], C[0:1])
# fdsi['fdsi'].isel(year=0).plot()
#
# def animate( self, i):
#     fdsi['fdsi'].isel(year=i).plot()
#
# anim = animation.FuncAnimation(fig, animate, frames=range(2,155), blit=False)
#
# def animate( self, i):
#     fdsi['fdsi'].isel(year=i).plot()

# %%
fdsi_da = fdsi['fdsi']

# %%
fig, ax = plt.subplots()
