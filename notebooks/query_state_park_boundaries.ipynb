# %% [markdown]
# # Query State Park Boundaries
# a. stein 2/17/22

# %%
import urllib.parse
import urllib.request

import geojson
import geopandas as gpd

# %% [markdown]
# ## Washington

# %%
wa_gdf = gpd.read_file('https://opendata.arcgis.com/datasets/3385b003af5248e59c1fa68e1411c446_0.geojson')
wa_gdf
# Out:
#      OBJECTID              ParkName                  Category  ParkCode  \
# 0           1             Alta Lake                State Park     61000
# 1           2         Anderson Lake                State Park     58001
# 2           3                Auburn       State Park Property     83503
# 3           4    Battle Ground Lake                State Park     41000
# 4           5              Bay View                State Park     54001
# ..        ...                   ...                       ...       ...
# 207       208  Wenatchee Confluence                State Park     67000
# 208       209        Westport Light                State Park     48004
# 209       210         Willapa Hills          State Park Trail     46007
# 210       211   Willie Keil's Grave  State Park Heritage Site     46004
# 211       212      Yakima Sportsman                State Park     77000
#
#                                                WebPage Abbrv  \
# 0               http://parks.state.wa.us/239/Alta-Lake   ALL
# 1           http://parks.state.wa.us/240/Anderson-Lake   ANL
# 2                                                        AUB
# 3      http://parks.state.wa.us/472/Battle-Ground-Lake   BGL
# 4                http://parks.state.wa.us/473/Bay-View   BAV
# ..                                                 ...   ...
# 207  http://parks.state.wa.us/286/Wenatchee-Confluence   WEC
# 208        http://parks.state.wa.us/284/Westport-Light   WEL
# 209                                                      WIH
# 210                                                      WKG
# 211      http://parks.state.wa.us/278/Yakima-Sportsman   YAS
#
#                                            Description  \
# 0    Alta Lake State Park is a 174-acre camping par...
# 1                                                 None
# 2                                                 None
# 3    Battle Ground Lake State Park is a camping par...
# 4    Bay View State Park is a 66-acre camping park ...
# ..                                                 ...
# 207  Wenatchee Confluence State Park is a 194-acre,...
# 208  Westport Light State Park is a 560-acre day-us...
# 209                                               None
# 210                                               None
# 211  Yakima Sportsman State Park is a 266-acre camp...
#
#                                              Imagelink  \
# 0    http://parks.state.wa.us/ImageRepository/Path?...
# 1                                                 None
# 2                                                 None
# 3    http://parks.state.wa.us/ImageRepository/Path?...
# 4    http://parks.state.wa.us/ImageRepository/Path?...
# ..                                                 ...
# 207  http://parks.state.wa.us/ImageRepository/Path?...
# 208  http://parks.state.wa.us/ImageRepository/Path?...
# 209                                               None
# 210                                               None
# 211  http://parks.state.wa.us/ImageRepository/Path?...
#
#                                     ManagementPlan_URL  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 207   https://www.parks.state.wa.us/352/Wenatchee-Area
# 208  https://www.parks.state.wa.us/348/South-Beach-...
# 209                                               None
# 210                                               None
# 211  https://www.parks.state.wa.us/353/Yakima-Sport...
#
#                                     ManagementPlan_PDF  Lat_Entrance  \
# 0                                                 None     48.032181
# 1                                                 None     48.014130
# 2                                                 None     47.333881
# 3                                                 None     45.802952
# 4                                                 None     48.487591
# ..                                                 ...           ...
# 207  https://www.parks.state.wa.us/DocumentCenter/V...     47.462360
# 208  https://www.parks.state.wa.us/DocumentCenter/V...     46.904099
# 209                                               None           NaN
# 210                                               None     46.645538
# 211  https://www.parks.state.wa.us/DocumentCenter/V...     46.591881
#
#      Long_Entrance       Acres                                   LABEL_LOCAL  \
# 0        -119.9347  174.474288                          Alta Lake State Park
# 1        -122.8075  496.403199                      Anderson Lake State Park
# 2        -122.2206    1.599684                    Auburn State Park Property
# 3        -122.4867  299.065669                 Battle Ground Lake State Park
# 4        -122.4802   66.257905                           Bay View State Park
# ..             ...         ...                                           ...
# 207      -120.3288  194.117483               Wenatchee Confluence State Park
# 208      -124.1112  559.822762                     Westport Light State Park
# 209            NaN  756.717335                Willapa Hills State Park Trail
# 210      -123.6610    0.351297  Willie Keil's Grave State Park Heritage Site
# 211      -120.4529  267.178999                   Yakima Sportsman State Park
#
#      SHAPE_Length    SHAPE_Area  \
# 0        0.103181  8.509869e-05
# 1        0.153846  2.420847e-04
# 2        0.005044  7.705107e-07
# 3        0.056478  1.400745e-04
# 4        0.037852  3.259054e-05
# ..            ...           ...
# 207      0.114732  9.369919e-05
# 208      0.076836  2.674714e-04
# 209      2.111139  3.595930e-04
# 210      0.001720  1.668029e-07
# 211      0.098875  1.269461e-04
#
#                                               geometry
# 0    MULTIPOLYGON (((-119.92753 48.02374, -119.9274...
# 1    MULTIPOLYGON (((-122.80452 48.01318, -122.8044...
# 2    MULTIPOLYGON (((-122.21938 47.33369, -122.2193...
# 3    MULTIPOLYGON (((-122.49553 45.79951, -122.4955...
# 4    MULTIPOLYGON (((-122.48136 48.49020, -122.4813...
# ..                                                 ...
# 207  MULTIPOLYGON (((-120.31875 47.47136, -120.3189...
# 208  MULTIPOLYGON (((-124.11647 46.88649, -124.1164...
# 209  MULTIPOLYGON (((-123.74756 46.68514, -123.7474...
# 210  MULTIPOLYGON (((-123.66135 46.64524, -123.6614...
# 211  MULTIPOLYGON (((-120.46599 46.59615, -120.4659...
#
# [212 rows x 17 columns]

# %%
wa_gdf.to_file('../data/wa_state_park_bounds.geojson')

# %%
gpd.read_file('../data/wa_state_park_bounds.geojson').head()
# Out:
#    OBJECTID            ParkName             Category  ParkCode  \
# 0         1           Alta Lake           State Park     61000
# 1         2       Anderson Lake           State Park     58001
# 2         3              Auburn  State Park Property     83503
# 3         4  Battle Ground Lake           State Park     41000
# 4         5            Bay View           State Park     54001
#
#                                            WebPage Abbrv  \
# 0           http://parks.state.wa.us/239/Alta-Lake   ALL
# 1       http://parks.state.wa.us/240/Anderson-Lake   ANL
# 2                                                    AUB
# 3  http://parks.state.wa.us/472/Battle-Ground-Lake   BGL
# 4            http://parks.state.wa.us/473/Bay-View   BAV
#
#                                          Description  \
# 0  Alta Lake State Park is a 174-acre camping par...
# 1                                               None
# 2                                               None
# 3  Battle Ground Lake State Park is a camping par...
# 4  Bay View State Park is a 66-acre camping park ...
#
#                                            Imagelink ManagementPlan_URL  \
# 0  http://parks.state.wa.us/ImageRepository/Path?...               None
# 1                                               None               None
# 2                                               None               None
# 3  http://parks.state.wa.us/ImageRepository/Path?...               None
# 4  http://parks.state.wa.us/ImageRepository/Path?...               None
#
#   ManagementPlan_PDF  Lat_Entrance  Long_Entrance       Acres  \
# 0               None     48.032181      -119.9347  174.474288
# 1               None     48.014130      -122.8075  496.403199
# 2               None     47.333881      -122.2206    1.599684
# 3               None     45.802952      -122.4867  299.065669
# 4               None     48.487591      -122.4802   66.257905
#
#                      LABEL_LOCAL  SHAPE_Length    SHAPE_Area  \
# 0           Alta Lake State Park      0.103181  8.509869e-05
# 1       Anderson Lake State Park      0.153846  2.420847e-04
# 2     Auburn State Park Property      0.005044  7.705107e-07
# 3  Battle Ground Lake State Park      0.056478  1.400745e-04
# 4            Bay View State Park      0.037852  3.259054e-05
#
#                                             geometry
# 0  MULTIPOLYGON (((-119.92753 48.02374, -119.9274...
# 1  MULTIPOLYGON (((-122.80452 48.01318, -122.8044...
# 2  MULTIPOLYGON (((-122.21938 47.33369, -122.2193...
# 3  MULTIPOLYGON (((-122.49553 45.79951, -122.4955...
# 4  MULTIPOLYGON (((-122.48136 48.49020, -122.4813...

# %% [markdown]
# That was easy

# %% [markdown]
# ## Oregon
