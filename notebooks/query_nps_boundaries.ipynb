# %% [markdown]
# # Query National Park Service Boundaries
#
# a. stein 1.18.22
#
# This notebook explores how to (and does) query data from the national park service (NPS) for geodata.

# %%
# %pylab inline

import urllib.parse
import urllib.request

import geojson
import geopandas as gpd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Following this site: https://support.esri.com/en/technical-article/000019645
# We need to deviate with this: https://stackoverflow.com/questions/44049679/geojson-to-shapefile-using-python
#
# Following is a combination to get it to work

# %%
# url that points to the nps boundary query page
url = 'https://services1.arcgis.com/fBc8EJBxQRMcHlei/arcgis/rest/services/+NPS_Land_Resources_Division_Boundary_and_Tract_Data_Service/FeatureServer/2/query'

# %%
# this is taken from the first hyperlink
# For Python 3
params = {'where': '1=1',
		   'geometryType': 'esriGeometryEnvelope',
		   'spatialRel': 'esriSpatialRelIntersects',
		   'relationParam': '',
		   'outFields': '*',
		   'returnGeometry': 'true',
		   'geometryPrecision':'',
		   'outSR': '',
		   'returnIdsOnly': 'false',
		   'returnCountOnly': 'false',
		   'orderByFields': '',
		   'groupByFieldsForStatistics': '',
		   'returnZ': 'false',
		   'returnM': 'false',
		   'returnDistinctValues': 'false',
		   'f': 'geojson',
		   }

encode_params = urllib.parse.urlencode(params).encode("utf-8")

# %%
# getting url request error
response = urllib.request.urlopen(url, encode_params)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipykernel_801398/3580652740.py in <module>
# ----> 1 response = urllib.request.urlopen(url, encode_params)
#
# /pool0/data/steinadi/.conda/envs/sedi/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /pool0/data/steinadi/.conda/envs/sedi/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# /pool0/data/steinadi/.conda/envs/sedi/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# /pool0/data/steinadi/.conda/envs/sedi/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# /pool0/data/steinadi/.conda/envs/sedi/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /pool0/data/steinadi/.conda/envs/sedi/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
data = geojson.loads(response.read())

# %%
with open('../data/nps_bounds.geojson', 'w') as f:
    geojson.dump(data,f)

# %%
# ?geojson.dump
# Out:
# Signature:
# geojson.dump(
#     obj,
#     fp,
#     cls=<class 'geojson.codec.GeoJSONEncoder'>,
#     allow_nan=False,
#     **kwargs,
# )
# Docstring: <no docstring>
# File:      /pool0/data/steinadi/.conda/envs/sedi/lib/python3.7/site-packages/geojson/codec.py
# Type:      function

# %%
# using geojson files seems to be just fine, so let's do that instead of clunky shapefiles

gdf = gpd.read_file('../data/nps_bounds.geojson')
gdf
# Out:
#      OBJECTID UNIT_CODE                                          GIS_Notes  \
# 0           1      APPA  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 1           2      WHHO  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 2           3      BRCR  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 3           4      MANZ  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 4           5      DRTO  Lands - http://landsnet.nps.gov/tractsnet/docu...
# ..        ...       ...                                                ...
# 422       423      ISRO  PRELIMINARY - Data has not completed the entir...
# 423       424      DELA  PRELIMINARY - Data has not completed the entir...
# 424       425      HART  PRELIMINARY - Data has not completed the entir...
# 425       426      MNRR  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 426       427      STGE  Lands - http://landsnet.nps.gov/tractsnet/docu...
#
#                                         UNIT_NAME      DATE_EDIT STATE REGION  \
# 0               Appalachian National Scenic Trail  1638835200000    ME     NE
# 1                                     White House  1275004800000    DC     NC
# 2    Brices Cross Roads National Battlefield Site  1129161600000    MS     SE
# 3                 Manzanar National Historic Site  1204588800000    CA     PW
# 4                      Dry Tortugas National Park  1194393600000    FL     SE
# ..                                            ...            ...   ...    ...
# 422                     Isle Royale National Park  1387324800000    MI     MW
# 423                Delaware National Scenic River  1539734400000    PA     NE
# 424       Harriet Tubman National Historical Park  1553126400000    NY     NE
# 425            Missouri National Recreation River  1578614400000    SD     MW
# 426       Ste. Geneviève National Historical Park  1622592000000    MO     MW
#
#      GNIS_ID                  UNIT_TYPE CREATED_BY  \
# 0    2766084      National Scenic Trail      Lands
# 1    2733430          Other Designation      Lands
# 2     667556  National Battlefield Site      Lands
# 3    1804731     National Historic Site      Lands
# 4     307632              National Park      Lands
# ..       ...                        ...        ...
# 422  1616980              National Park      Lands
# 423     need      National Scenic River      Lands
# 424     need   National Historical Park      Lands
# 425  2733411  National Recreation River      Lands
# 426     need   National Historical Park      Lands
#
#                                               METADATA  \
# 0    https://irma.nps.gov/DataStore/Reference/Profi...
# 1    https://irma.nps.gov/DataStore/Reference/Profi...
# 2    https://irma.nps.gov/DataStore/Reference/Profi...
# 3    https://irma.nps.gov/DataStore/Reference/Profi...
# 4    https://irma.nps.gov/DataStore/Reference/Profi...
# ..                                                 ...
# 422  Preliminary data. Contact the Land Resources P...
# 423  Preliminary data. Contact the Land Resources P...
# 424  Preliminary data. Contact the Land Resources P...
# 425  https://irma.nps.gov/DataStore/Reference/Profi...
# 426  https://irma.nps.gov/DataStore/Reference/Profi...
#
#                            PARKNAME   CreationDate               Creator  \
# 0                       Appalachian  1641465825000                  WASO
# 1    President's Park (White House)  1641465875000                  WASO
# 2                Brices Cross Roads  1641465745000                  WASO
# 3                          Manzanar  1641465864000                  WASO
# 4                      Dry Tortugas  1641465753000                  WASO
# ..                              ...            ...                   ...
# 422                     Isle Royale  1578608163000  SCarlton@nps.gov_nps
# 423                        Delaware  1578608163000  SCarlton@nps.gov_nps
# 424                  Harriet Tubman  1578608163000  SCarlton@nps.gov_nps
# 425                        Missouri  1585972697000  RJohnson@nps.gov_nps
# 426                  Ste. Geneviève  1625281804000  RJohnson@nps.gov_nps
#
#           EditDate                Editor  \
# 0    1641465825000                  WASO
# 1    1641465875000                  WASO
# 2    1641465745000                  WASO
# 3    1641465864000                  WASO
# 4    1641465753000                  WASO
# ..             ...                   ...
# 422  1578608163000  SCarlton@nps.gov_nps
# 423  1578608163000  SCarlton@nps.gov_nps
# 424  1578608163000  SCarlton@nps.gov_nps
# 425  1585972697000  RJohnson@nps.gov_nps
# 426  1625281804000  RJohnson@nps.gov_nps
#
#                                  GlobalID   Shape__Area  Shape__Length  \
# 0    3923bec4-1652-41ca-a444-84fead65aba5  1.483097e+09   5.738046e+06
# 1    c1455489-c4ea-40e8-b063-187c68391fac  1.227879e+05   1.366089e+03
# 2    338b4ffd-b37e-4062-9983-6419939ef145  5.930141e+03   3.421651e+02
# 3    88da484b-186e-4cc7-bfb0-68fed2fb61ed  5.134513e+06   8.941593e+03
# 4    b7d7dc12-29e6-4669-a9ed-448983b3f478  3.226821e+08   6.974401e+04
# ..                                    ...           ...            ...
# 422  5e63c781-e9aa-4390-a47b-dc1b451240bc  4.985802e+09   3.461377e+05
# 423  06a4d82a-43d7-4685-bf1f-7792459fd203  1.997406e+07   2.421450e+05
# 424  0860bc94-332d-4add-b733-8f9d065a40af  2.563835e+05   2.544291e+03
# 425  826e39a9-cbd7-4c37-af91-1c4a6f6d684b  5.140014e+08   6.375951e+05
# 426  1ef52543-3190-4113-b709-bb6dcaf84d19  1.040759e+05   2.418901e+03
#
#                                               geometry
# 0    MULTIPOLYGON (((-84.23454 34.62248, -84.23439 ...
# 1    POLYGON ((-77.03526 38.89634, -77.03526 38.896...
# 2    POLYGON ((-88.72947 34.50599, -88.72860 34.506...
# 3    POLYGON ((-118.15405 36.71756, -118.15515 36.7...
# 4    MULTIPOLYGON (((-82.77445 24.70843, -82.76523 ...
# ..                                                 ...
# 422  MULTIPOLYGON (((-88.56271 47.12219, -88.56304 ...
# 423  POLYGON ((-74.75803 41.34187, -74.75839 41.341...
# 424  MULTIPOLYGON (((-76.55819 42.91144, -76.55805 ...
# 425  MULTIPOLYGON (((-97.29310 42.87327, -97.29197 ...
# 426  MULTIPOLYGON (((-90.01636 37.94761, -90.01557 ...
#
# [427 rows x 20 columns]

# %%
gdf[gdf.STATE == 'WA']
# Out:
#      OBJECTID UNIT_CODE                                          GIS_Notes  \
# 17         18      LACH  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 49         50      MIIN  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 87         88      NOCA  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 93         94      ROLA  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 202       203      MORA  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 246       247      FOVA  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 306       307      WHMI  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 397       398      OLYM  PRELIMINARY - Data has not completed the entir...
# 400       401      SAJH  PRELIMINARY - Data has not completed the entir...
# 408       409      LEWI  PRELIMINARY - Data has not completed the entir...
# 409       410      NEPE  PRELIMINARY - Data has not completed the entir...
# 410       411      LARO  PRELIMINARY - Data has not completed the entir...
# 413       414      EBLA  PRELIMINARY - Data has not completed the entir...
#
#                                       UNIT_NAME      DATE_EDIT STATE REGION  \
# 17         Lake Chelan National Recreation Area  1623628800000    WA     PW
# 49              Minidoka National Historic Site  1444867200000    WA     PW
# 87                 North Cascades National Park  1474848000000    WA     PW
# 93           Ross Lake National Recreation Area  1516233600000    WA     PW
# 202                 Mount Rainier National Park  1447718400000    WA     PW
# 246       Fort Vancouver National Historic Site  1299110400000    WA     PW
# 306      Whitman Mission National Historic Site  1319673600000    WA     PW
# 397                       Olympic National Park  1429660800000    WA     PW
# 400    San Juan Island National Historical Park  1437696000000    WA     PW
# 408    Lewis and Clark National Historical Park  1568073600000    WA     PW
# 409          Nez Perce National Historical Park  1387324800000    WA     PW
# 410     Lake Roosevelt National Recreation Area  1429660800000    WA     PW
# 413  Ebey's Landing National Historical Reserve  1429660800000    WA     PW
#
#      GNIS_ID                    UNIT_TYPE CREATED_BY  \
# 17   1528425     National Recreation Area      Lands
# 49   2766708       National Historic Site      Lands
# 87   1528421                National Park      Lands
# 93   1528419     National Recreation Area      Lands
# 202  1528416                National Park      Lands
# 246  1504974       National Historic Site      Lands
# 306  1531185       National Historic Site      Lands
# 397  1530459                National Park      Lands
# 400  1534055     National Historical Park      Lands
# 408  2055170     National Historical Park      Lands
# 409   394735     National Historical Park      Lands
# 410  1531834     National Recreation Area      Lands
# 413  1888910  National Historical Reserve      Lands
#
#                                               METADATA         PARKNAME  \
# 17   https://irma.nps.gov/DataStore/Reference/Profi...      Lake Chelan
# 49   https://irma.nps.gov/DataStore/Reference/Profi...         Minidoka
# 87   https://irma.nps.gov/DataStore/Reference/Profi...   North Cascades
# 93   https://irma.nps.gov/DataStore/Reference/Profi...        Ross Lake
# 202  https://irma.nps.gov/DataStore/Reference/Profi...    Mount Rainier
# 246  https://irma.nps.gov/DataStore/Reference/Profi...   Fort Vancouver
# 306  https://irma.nps.gov/DataStore/Reference/Profi...  Whitman Mission
# 397  Preliminary data. Contact the Land Resources P...          Olympic
# 400  Preliminary data. Contact the Land Resources P...  San Juan Island
# 408  Preliminary data. Contact the Land Resources P...  Lewis and Clark
# 409  Preliminary data. Contact the Land Resources P...        Nez Perce
# 410  Preliminary data. Contact the Land Resources P...   Lake Roosevelt
# 413  Preliminary data. Contact the Land Resources P...   Ebey's Landing
#
#       CreationDate               Creator       EditDate                Editor  \
# 17   1641465862000                  WASO  1641465862000                  WASO
# 49   1641465864000                  WASO  1641465864000                  WASO
# 87   1641465865000                  WASO  1641465865000                  WASO
# 93   1641465867000                  WASO  1641465867000                  WASO
# 202  1641465865000                  WASO  1641465865000                  WASO
# 246  1641465769000                  WASO  1641465769000                  WASO
# 306  1641465876000                  WASO  1641465876000                  WASO
# 397  1578608163000  SCarlton@nps.gov_nps  1578608163000  SCarlton@nps.gov_nps
# 400  1578608163000  SCarlton@nps.gov_nps  1578608163000  SCarlton@nps.gov_nps
# 408  1578608163000  SCarlton@nps.gov_nps  1578608163000  SCarlton@nps.gov_nps
# 409  1578608163000  SCarlton@nps.gov_nps  1578608163000  SCarlton@nps.gov_nps
# 410  1578608163000  SCarlton@nps.gov_nps  1578608163000  SCarlton@nps.gov_nps
# 413  1578608163000  SCarlton@nps.gov_nps  1578608163000  SCarlton@nps.gov_nps
#
#                                  GlobalID   Shape__Area  Shape__Length  \
# 17   fbb48ff0-6586-4c58-b4f3-1d71bb4212fe  5.760042e+08   1.364468e+05
# 49   3d275170-90d1-44fe-bac5-cdab70c70345  2.998805e+06   1.206120e+04
# 87   f8fee043-cd94-444f-85bb-bccad4e04dcf  4.656136e+09   5.359118e+05
# 93   644bac60-adc0-4b60-b233-5b99e18aa63e  1.087618e+09   2.689396e+05
# 202  99e54d17-7e45-4d60-92a0-c16d312534ea  2.045641e+09   2.176600e+05
# 246  a69b373d-7809-48fc-ac82-b43d4fa5f456  1.723305e+06   1.176582e+04
# 306  a56c8a50-4f89-43a2-a3f9-14fb9c2f4896  1.165191e+06   6.356421e+03
# 397  d568927b-56f4-4f49-a52a-b8ab9f7676a3  8.203591e+09   1.158605e+06
# 400  885ae402-ab5a-48d1-91bd-4114a8abc323  1.960832e+07   4.016415e+04
# 408  6ceaf8b1-2e9e-47a5-8538-c9909ec055a3  3.065070e+07   7.983376e+04
# 409  2361bdbb-5252-4469-a3d3-35481928583a  3.621245e+07   8.824532e+04
# 410  83f0a6b9-bba3-409c-b71b-ad33e5983c13  7.177148e+08   1.179061e+06
# 413  d269affb-19ba-47ad-b506-42230a6fdea2  1.643379e+08   6.700486e+04
#
#                                               geometry
# 17   POLYGON ((-120.62256 48.26911, -120.63218 48.2...
# 49   MULTIPOLYGON (((-114.25225 42.67831, -114.2528...
# 87   MULTIPOLYGON (((-121.06308 48.45964, -121.0632...
# 93   POLYGON ((-121.38888 48.58176, -121.38952 48.5...
# 202  MULTIPOLYGON (((-122.12686 46.75926, -122.1242...
# 246  MULTIPOLYGON (((-122.66901 45.62006, -122.6690...
# 306  POLYGON ((-118.46524 46.04075, -118.47091 46.0...
# 397  MULTIPOLYGON (((-124.38063 47.60211, -124.3807...
# 400  MULTIPOLYGON (((-123.00504 48.46942, -123.0049...
# 408  MULTIPOLYGON (((-123.93157 45.98449, -123.9316...
# 409  MULTIPOLYGON (((-117.22387 45.33762, -117.2238...
# 410  MULTIPOLYGON (((-118.98813 47.93675, -118.9882...
# 413  POLYGON ((-122.68070 48.25844, -122.68073 48.2...

# %%
gdf[(gdf.STATE == 'WA') | (gdf.STATE == 'OR')]
# Out:
#      OBJECTID UNIT_CODE                                          GIS_Notes  \
# 17         18      LACH  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 20         21      JODA  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 49         50      MIIN  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 80         81      CRLA  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 82         83      ORCA  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 87         88      NOCA  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 93         94      ROLA  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 202       203      MORA  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 246       247      FOVA  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 306       307      WHMI  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 397       398      OLYM  PRELIMINARY - Data has not completed the entir...
# 400       401      SAJH  PRELIMINARY - Data has not completed the entir...
# 408       409      LEWI  PRELIMINARY - Data has not completed the entir...
# 409       410      NEPE  PRELIMINARY - Data has not completed the entir...
# 410       411      LARO  PRELIMINARY - Data has not completed the entir...
# 413       414      EBLA  PRELIMINARY - Data has not completed the entir...
#
#                                        UNIT_NAME      DATE_EDIT STATE REGION  \
# 17          Lake Chelan National Recreation Area  1623628800000    WA     PW
# 20        John Day Fossil Beds National Monument  1436313600000    OR     PW
# 49               Minidoka National Historic Site  1444867200000    WA     PW
# 80                     Crater Lake National Park  1496620800000    OR     PW
# 82   Oregon Caves National Monument and Preserve  1623628800000    OR     PW
# 87                  North Cascades National Park  1474848000000    WA     PW
# 93            Ross Lake National Recreation Area  1516233600000    WA     PW
# 202                  Mount Rainier National Park  1447718400000    WA     PW
# 246        Fort Vancouver National Historic Site  1299110400000    WA     PW
# 306       Whitman Mission National Historic Site  1319673600000    WA     PW
# 397                        Olympic National Park  1429660800000    WA     PW
# 400     San Juan Island National Historical Park  1437696000000    WA     PW
# 408     Lewis and Clark National Historical Park  1568073600000    WA     PW
# 409           Nez Perce National Historical Park  1387324800000    WA     PW
# 410      Lake Roosevelt National Recreation Area  1429660800000    WA     PW
# 413   Ebey's Landing National Historical Reserve  1429660800000    WA     PW
#
#      GNIS_ID                    UNIT_TYPE CREATED_BY  \
# 17   1528425     National Recreation Area      Lands
# 20   1133439            National Monument      Lands
# 49   2766708       National Historic Site      Lands
# 80   1163670                National Park      Lands
# 82   1147260            National Monument      Lands
# 87   1528421                National Park      Lands
# 93   1528419     National Recreation Area      Lands
# 202  1528416                National Park      Lands
# 246  1504974       National Historic Site      Lands
# 306  1531185       National Historic Site      Lands
# 397  1530459                National Park      Lands
# 400  1534055     National Historical Park      Lands
# 408  2055170     National Historical Park      Lands
# 409   394735     National Historical Park      Lands
# 410  1531834     National Recreation Area      Lands
# 413  1888910  National Historical Reserve      Lands
#
#                                               METADATA              PARKNAME  \
# 17   https://irma.nps.gov/DataStore/Reference/Profi...           Lake Chelan
# 20   https://irma.nps.gov/DataStore/Reference/Profi...  John Day Fossil Beds
# 49   https://irma.nps.gov/DataStore/Reference/Profi...              Minidoka
# 80   https://irma.nps.gov/DataStore/Reference/Profi...           Crater Lake
# 82   https://irma.nps.gov/DataStore/Reference/Profi...          Oregon Caves
# 87   https://irma.nps.gov/DataStore/Reference/Profi...        North Cascades
# 93   https://irma.nps.gov/DataStore/Reference/Profi...             Ross Lake
# 202  https://irma.nps.gov/DataStore/Reference/Profi...         Mount Rainier
# 246  https://irma.nps.gov/DataStore/Reference/Profi...        Fort Vancouver
# 306  https://irma.nps.gov/DataStore/Reference/Profi...       Whitman Mission
# 397  Preliminary data. Contact the Land Resources P...               Olympic
# 400  Preliminary data. Contact the Land Resources P...       San Juan Island
# 408  Preliminary data. Contact the Land Resources P...       Lewis and Clark
# 409  Preliminary data. Contact the Land Resources P...             Nez Perce
# 410  Preliminary data. Contact the Land Resources P...        Lake Roosevelt
# 413  Preliminary data. Contact the Land Resources P...        Ebey's Landing
#
#       CreationDate               Creator       EditDate                Editor  \
# 17   1641465862000                  WASO  1641465862000                  WASO
# 20   1641465894000                  WASO  1641465894000                  WASO
# 49   1641465864000                  WASO  1641465864000                  WASO
# 80   1641465752000                  WASO  1641465752000                  WASO
# 82   1641465866000                  WASO  1641465866000                  WASO
# 87   1641465865000                  WASO  1641465865000                  WASO
# 93   1641465867000                  WASO  1641465867000                  WASO
# 202  1641465865000                  WASO  1641465865000                  WASO
# 246  1641465769000                  WASO  1641465769000                  WASO
# 306  1641465876000                  WASO  1641465876000                  WASO
# 397  1578608163000  SCarlton@nps.gov_nps  1578608163000  SCarlton@nps.gov_nps
# 400  1578608163000  SCarlton@nps.gov_nps  1578608163000  SCarlton@nps.gov_nps
# 408  1578608163000  SCarlton@nps.gov_nps  1578608163000  SCarlton@nps.gov_nps
# 409  1578608163000  SCarlton@nps.gov_nps  1578608163000  SCarlton@nps.gov_nps
# 410  1578608163000  SCarlton@nps.gov_nps  1578608163000  SCarlton@nps.gov_nps
# 413  1578608163000  SCarlton@nps.gov_nps  1578608163000  SCarlton@nps.gov_nps
#
#                                  GlobalID   Shape__Area  Shape__Length  \
# 17   fbb48ff0-6586-4c58-b4f3-1d71bb4212fe  5.760042e+08   1.364468e+05
# 20   6a8d9167-6eed-4acd-9055-7cb1311049e0  1.170267e+08   1.178536e+05
# 49   3d275170-90d1-44fe-bac5-cdab70c70345  2.998805e+06   1.206120e+04
# 80   a804733f-87a4-4e56-95f5-84e51179e5e0  1.382854e+09   1.754375e+05
# 82   8a5f44ae-5110-437c-a46e-f3e3efc23e70  3.333237e+07   2.847476e+04
# 87   f8fee043-cd94-444f-85bb-bccad4e04dcf  4.656136e+09   5.359118e+05
# 93   644bac60-adc0-4b60-b233-5b99e18aa63e  1.087618e+09   2.689396e+05
# 202  99e54d17-7e45-4d60-92a0-c16d312534ea  2.045641e+09   2.176600e+05
# 246  a69b373d-7809-48fc-ac82-b43d4fa5f456  1.723305e+06   1.176582e+04
# 306  a56c8a50-4f89-43a2-a3f9-14fb9c2f4896  1.165191e+06   6.356421e+03
# 397  d568927b-56f4-4f49-a52a-b8ab9f7676a3  8.203591e+09   1.158605e+06
# 400  885ae402-ab5a-48d1-91bd-4114a8abc323  1.960832e+07   4.016415e+04
# 408  6ceaf8b1-2e9e-47a5-8538-c9909ec055a3  3.065070e+07   7.983376e+04
# 409  2361bdbb-5252-4469-a3d3-35481928583a  3.621245e+07   8.824532e+04
# 410  83f0a6b9-bba3-409c-b71b-ad33e5983c13  7.177148e+08   1.179061e+06
# 413  d269affb-19ba-47ad-b506-42230a6fdea2  1.643379e+08   6.700486e+04
#
#                                               geometry
# 17   POLYGON ((-120.62256 48.26911, -120.63218 48.2...
# 20   MULTIPOLYGON (((-119.63853 44.49838, -119.6436...
# 49   MULTIPOLYGON (((-114.25225 42.67831, -114.2528...
# 80   MULTIPOLYGON (((-122.88278 42.33695, -122.8828...
# 82   MULTIPOLYGON (((-123.64524 42.16207, -123.6452...
# 87   MULTIPOLYGON (((-121.06308 48.45964, -121.0632...
# 93   POLYGON ((-121.38888 48.58176, -121.38952 48.5...
# 202  MULTIPOLYGON (((-122.12686 46.75926, -122.1242...
# 246  MULTIPOLYGON (((-122.66901 45.62006, -122.6690...
# 306  POLYGON ((-118.46524 46.04075, -118.47091 46.0...
# 397  MULTIPOLYGON (((-124.38063 47.60211, -124.3807...
# 400  MULTIPOLYGON (((-123.00504 48.46942, -123.0049...
# 408  MULTIPOLYGON (((-123.93157 45.98449, -123.9316...
# 409  MULTIPOLYGON (((-117.22387 45.33762, -117.2238...
# 410  MULTIPOLYGON (((-118.98813 47.93675, -118.9882...
# 413  POLYGON ((-122.68070 48.25844, -122.68073 48.2...

# %%
path = '../data/pw_nps_bounds.geojson'

try:
    os.remove(path)
except:
    pass

gdf[gdf.REGION == 'PW'].to_file(path)

# %%
pnw_nps_gpd = gpd.read_file('../data/pw_nps_bounds.geojson')
pnw_nps_gpd.head()
# Out:
#    OBJECTID UNIT_CODE                                          GIS_Notes  \
# 0         4      MANZ  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 1         8      MUWO  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 2        18      LACH  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 3        21      JODA  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 4        50      MIIN  Lands - http://landsnet.nps.gov/tractsnet/docu...
#
#                                 UNIT_NAME      DATE_EDIT STATE REGION  \
# 0         Manzanar National Historic Site  1204588800000    CA     PW
# 1            Muir Woods National Monument  1568851200000    CA     PW
# 2    Lake Chelan National Recreation Area  1623628800000    WA     PW
# 3  John Day Fossil Beds National Monument  1436313600000    OR     PW
# 4         Minidoka National Historic Site  1444867200000    WA     PW
#
#    GNIS_ID                 UNIT_TYPE CREATED_BY  \
# 0  1804731    National Historic Site      Lands
# 1   229295         National Monument      Lands
# 2  1528425  National Recreation Area      Lands
# 3  1133439         National Monument      Lands
# 4  2766708    National Historic Site      Lands
#
#                                             METADATA              PARKNAME  \
# 0  https://irma.nps.gov/DataStore/Reference/Profi...              Manzanar
# 1  https://irma.nps.gov/DataStore/Reference/Profi...            Muir Woods
# 2  https://irma.nps.gov/DataStore/Reference/Profi...           Lake Chelan
# 3  https://irma.nps.gov/DataStore/Reference/Profi...  John Day Fossil Beds
# 4  https://irma.nps.gov/DataStore/Reference/Profi...              Minidoka
#
#     CreationDate Creator       EditDate Editor  \
# 0  1641465864000    WASO  1641465864000   WASO
# 1  1641465911000    WASO  1641465911000   WASO
# 2  1641465862000    WASO  1641465862000   WASO
# 3  1641465894000    WASO  1641465894000   WASO
# 4  1641465864000    WASO  1641465864000   WASO
#
#                                GlobalID   Shape__Area  Shape__Length  \
# 0  88da484b-186e-4cc7-bfb0-68fed2fb61ed  5.134513e+06    8941.593062
# 1  8d63f7eb-43ae-44d8-90fd-01379b6f6097  3.614088e+06   14889.162369
# 2  fbb48ff0-6586-4c58-b4f3-1d71bb4212fe  5.760042e+08  136446.833337
# 3  6a8d9167-6eed-4acd-9055-7cb1311049e0  1.170267e+08  117853.622460
# 4  3d275170-90d1-44fe-bac5-cdab70c70345  2.998805e+06   12061.195418
#
#                                             geometry
# 0  POLYGON ((-118.15405 36.71756, -118.15515 36.7...
# 1  MULTIPOLYGON (((-122.56676 37.88867, -122.5669...
# 2  POLYGON ((-120.62256 48.26911, -120.63218 48.2...
# 3  MULTIPOLYGON (((-119.63853 44.49838, -119.6436...
# 4  MULTIPOLYGON (((-114.25225 42.67831, -114.2528...

# %%
states_url = 'http://eric.clst.org/assets/wiki/uploads/Stuff/gz_2010_us_040_00_5m.json'
states_gdf = gpd.read_file(states_url)

# %%
states_gdf.head()
# Out:
#         GEO_ID STATE        NAME LSAD  CENSUSAREA  \
# 0  0400000US01    01     Alabama        50645.326
# 1  0400000US02    02      Alaska       570640.950
# 2  0400000US04    04     Arizona       113594.084
# 3  0400000US05    05    Arkansas        52035.477
# 4  0400000US06    06  California       155779.220
#
#                                             geometry
# 0  MULTIPOLYGON (((-88.12466 30.28364, -88.08681 ...
# 1  MULTIPOLYGON (((-166.10574 53.98861, -166.0752...
# 2  POLYGON ((-112.53859 37.00067, -112.53454 37.0...
# 3  POLYGON ((-94.04296 33.01922, -94.04304 33.079...
# 4  MULTIPOLYGON (((-122.42144 37.86997, -122.4213...

# %%
set(pnw_nps_gpd.STATE)
# Out:
# {'AS', 'CA', 'GU', 'HI', 'ID', 'MT', 'NV', 'OR', 'WA'}

# %%
wa_or_nps_gpd = pnw_nps_gpd[(pnw_nps_gpd.STATE == 'WA') | (pnw_nps_gpd.STATE == 'OR')]

# %%
pnw_states = states_gdf[(states_gdf.NAME == 'Washington') | (states_gdf.NAME == 'Oregon')] #| (states_gdf.NAME == 'Alaska')]

# %%
fig, ax = plt.subplots(figsize=(15,15))

pnw_states.plot(ax=ax, facecolor='grey', edgecolor='k')
wa_or_nps_gpd.plot(ax=ax, facecolor='r', edgecolor='k', linewidth=0.1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# That's looking like a better extent, let's check what parks that inlcudes

# %%
wa_or_nps_gpd.UNIT_NAME
# Out:
# 2            Lake Chelan National Recreation Area
# 3          John Day Fossil Beds National Monument
# 4                 Minidoka National Historic Site
# 11                      Crater Lake National Park
# 12    Oregon Caves National Monument and Preserve
# 13                   North Cascades National Park
# 14             Ross Lake National Recreation Area
# 29                    Mount Rainier National Park
# 36          Fort Vancouver National Historic Site
# 43         Whitman Mission National Historic Site
# 55                          Olympic National Park
# 56       San Juan Island National Historical Park
# 58       Lewis and Clark National Historical Park
# 59             Nez Perce National Historical Park
# 60        Lake Roosevelt National Recreation Area
# 61     Ebey's Landing National Historical Reserve
# Name: UNIT_NAME, dtype: object

# %% [markdown]
# Real quick grab the list of parks I have visitation data for  ...

# %% [markdown]
# ['Crater Lake', 'John Day Fossil Beds National Monument', 'Klondike Gold Rush National Recreation Area', 'Lake Chelan National Recreation Area', 'Lake Roosevelt National Recreation Area', 'Lewis and Clark National Historic Place', 'Mount Rainer National Park', 'North Cascades National Park', 'Olympic National Park', 'Oregon Caves National Park and National Monument', 'Ross Lake National Recreation Area', 'San Juan Island National Historic Park']

# %% [markdown]
# Alright, I have all the boundaries (except for the `Klondike Gold Rush National Recreation Area` ... probably since it's in Alaska ... we shouldn't be looking at that anywho) for the parks I have data for, but also some more ... let's trim that down.

# %%
pnw_nps_select = wa_or_nps_gpd.loc[[11,3,2,60,58,29,13,55,12,14,56]]

# %%
fig, ax = plt.subplots(figsize=(15,15))

pnw_states.plot(ax=ax, facecolor='grey', edgecolor='k')
pnw_nps_select.plot(ax=ax, facecolor='r', edgecolor='k', linewidth=0.1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Alright, let's save that out.

# %%
path = '../data/pw_nps_select_geo.geojson'

try:
    os.remove(path)
except:
    pass

pnw_nps_select.to_file(path)
