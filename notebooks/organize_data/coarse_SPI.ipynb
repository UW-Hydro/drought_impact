# %%
import numpy as np
import xarray as xr
from tqdm.autonotebook import tqdm
from scipy.io import loadmat
import h5py

import matplotlib.pyplot as plt

# %%
spi_path = '/pool0/home/steinadi/data/drought/drought_impact/data/drought_measures/spi/coarse'

# %%
f = h5py.File(f'{spi_path}/pr_30d.mat', 'r')
data = f.get('n')
data = np.array(data)

# %%
data.shape
# Out:
# (585, 1386, 44, 73)

# %%
xr.open_dataset('/pool0/home/steinadi/data/drought/drought_impact/data/drought_measures/spi/CONUS_105W/spi_1y.nc').sel(time=slice('2000','2022'))
# Out:
# <xarray.Dataset>
# Dimensions:  (x: 525, y: 702, time: 1606)
# Coordinates:
#   * x        (x) float64 -2.893e+06 -2.889e+06 ... -6.674e+05 -6.632e+05
#   * y        (y) float64 3.251e+06 3.246e+06 3.242e+06 ... 2.717e+05 2.674e+05
#   * time     (time) datetime64[ns] 2000-01-05 2000-01-10 ... 2021-12-31
# Data variables:
#     crs      int64 ...
#     spi      (time, y, x) float32 ...

# %% [markdown]
# Okay, that shape seems way too small. Also I have no idea what the first coordinate is.

# %% [markdown]
# Let's see if coarsening SPI based on the mean even speeds things up enough
